# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy.random import randn, randint

# %matplotlib inline

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
iris.plot(kind='bar',legend=True)
# Out:
# <AxesSubplot:>

# %%
df = iris.cumsum()

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
x = iris.drop(['sepal_length','petal_length'], axis = 1)
y = iris[['sepal_length', 'petal_length']]

# %%
x
# Out:
#      sepal_width  petal_width    species
# 0            3.5          0.2     setosa
# 1            3.0          0.2     setosa
# 2            3.2          0.2     setosa
# 3            3.1          0.2     setosa
# 4            3.6          0.2     setosa
# ..           ...          ...        ...
# 145          3.0          2.3  virginica
# 146          2.5          1.9  virginica
# 147          3.0          2.0  virginica
# 148          3.4          2.3  virginica
# 149          3.0          1.8  virginica
#
# [150 rows x 3 columns]

# %%
y
# Out:
#      sepal_length  petal_length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# ..            ...           ...
# 145           6.7           5.2
# 146           6.3           5.0
# 147           6.5           5.2
# 148           6.2           5.4
# 149           5.9           5.1
#
# [150 rows x 2 columns]

# %%
ax = x.plot()
y.plot(ax=ax, figsize=(16,9), legend=True, secondary_y=True)
plt.show()

# %%
data = pd.DataFrame(randn(10,4), columns=['a','b','c','d'])

# %%
data
# Out:
#           a         b         c         d
# 0  0.919032 -1.193392  1.552755  1.343433
# 1  0.344362 -0.011268  0.183164  0.483219
# 2 -0.660589  0.267513 -0.348451 -2.974095
# 3  0.104483 -0.838529  0.595555  1.485540
# 4 -0.124065 -0.600448  0.472560 -1.013559
# 5 -0.270394 -1.594414 -1.602632 -0.005060
# 6 -0.006207  0.485221  0.307246 -1.393064
# 7 -0.122081  2.385585 -0.294105  0.868250
# 8  0.482879  0.187025  0.411332  0.122580
# 9  1.301887  1.854423  1.570693  0.294368

# %%
data.plot(kind='barh', figsize=(16,9), stacked=True)
# Out:
# <AxesSubplot:>

# %%
ax = iris['petal_length'].plot.hist(bins=50)
iris['sepal_length'].plot.hist(bins=50,ax=ax,color='r', alpha=0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot.hist(bins = 50,subplots=True, layout=(2,2), figsize=(16,9))
plt.tight_layout()
plt.show()

# %%
df = iris.drop('species' , axis = 1)

# %%
df.diff().hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
iris.plot.box(figsize=(16,9), color='r')
# Out:
# <AxesSubplot:>

# %%
ax = iris.plot.scatter(x='sepal_length', y='petal_length', color='r')
iris.plot.scatter(x='sepal_length', y='petal_width', ax=ax, label='length', c = 'g')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
pd.plotting.scatter_matrix(iris, diagonal='hist', color='red',ax= ax, figsize=(16,9))
# Out:
# <ipython-input-61-99611fe5c957>:1: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   pd.plotting.scatter_matrix(iris, diagonal='hist', color='red',ax= ax, figsize=(16,9))
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
# ...
