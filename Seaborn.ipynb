# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker', style='sex')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, style='size')

# %%
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
sns.relplot(x='total_bill', y='tip', data=tips, style='smoker')

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill', y='tip', data=tips, size='size', sizes=(50,200))

# %%
from numpy.random import randint, randn

# %%
df= pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))

# %%
sns.relplot(x='time', y='value', data= df, kind='line')

# %%
fmri = sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
fig, ax =plt.subplots()
sns.relplot(x= 'timepoint', y='signal', kind='line', data = fmri)

# %%
sns.relplot(x='timepoint', y='signal', data=fmri, label='Signal', kind='line', ci = False, height=4, aspect= 2)
plt.legend()

# %%
sns.relplot(x='timepoint', y='signal', hue='event', data=fmri, label='Signal', marker=True, kind='line', ci = False, height=4, aspect= 2)

# %%
dots = sns.load_dataset('dots').query("align == 'dots'")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(x='time', y='firing_rate', data=dots, kind='line')

# %%
sns.relplot(x='time', y='firing_rate', data=dots, kind='line', hue='coherence', style='choice')

# %%
pallette = sns.cubehelix_palette(light = 0.4,  n_colors= 6)
sns.relplot(x='time', y='firing_rate', data=dots, kind='line', hue='coherence', style='choice', palette= pallette)

# %%
sns.relplot(x='time', y='firing_rate', data=dots, kind='line', hue='coherence', style='choice', palette= pallette, size='choice')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', col = 'day', data=tips, col_wrap=2)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', col = 'sex', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', col = 'time', data=tips, row = 'day')

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x='timepoint', y='signal', style='event', hue='region', data=fmri, ci=68, marker=True, err_style='bars')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x='timepoint', y='signal', style='event', hue='region', data=fmri.query("region == 'frontal'"), ci=68, marker=True, err_style='bars')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x='timepoint', y='signal', style='event', hue='region', data=fmri.query("region == 'frontal'"), ci=68, marker=True, err_style='bars', estimator=None)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(x= 'total_bill', y='tip', data=tips, hue='smoker', style='time', size= 'size', ci = False, legend=True, sizes= (20,100))
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day', y='size', data=tips, height=5, aspect=4, sizes=(10,100), jitter=False)

# %%
sns.catplot(x='day', y='total_bill', data=tips, hue='size', kind='swarm')

# %%
sns.catplot(x='smoker', y='tip', data=tips, order=['No', 'Yes'])

# %%
sns.catplot(x='day', y='total_bill', kind='box', data=tips)

# %%
diamond = sns.load_dataset('diamonds')

# %%
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x='color', y='price', data= diamond, kind='boxen')

# %%
sns.catplot(x='color', y='price', data= diamond, kind='boxen', hue='cut', height=5, aspect=3)

# %%
sns.catplot(x='total_bill', y='day', data=tips, kind='violin')

# %%
g= sns.catplot(x='total_bill', y= 'day', data=tips, kind='swarm', color='k')
sns.violinplot(x='total_bill', y='day', data=tips, ax=g.ax, hue='sex', split=True, height=4, aspect=3)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(x='sex', y='survived', data=titanic, kind='bar', hue='class')

# %%
sns.catplot(x='sex', y='survived', data=titanic, kind='bar', hue='class', palette='ch:0.5')

# %%
sns.pointplot(x= 'sex', y='survived', data=titanic, hue='class', markers = 'x', linestyles='--',errwidth=2)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
x = tips['total_bill']
y=  tips['tip']

# %%
sns.jointplot(x, y)
# Out:
# C:\Users\sarim\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(x, y, kind = 'kde', color='r')
# Out:
# C:\Users\sarim\anaconda3\envs\myenv\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(tips, hue = 'smoker',kind='kde')

# %%
g = sns.PairGrid(tips)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.scatterplot)

# %%
sns.regplot(x='total_bill', y='tip', data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
def sinplot(flip=1):
    x = np.linspace(0,14,100)
    for i in range(1,7):
        plt.plot(x, np.sin(x + i*0.5)*(7-i)*flip)

# %%
sinplot()

# %%
sinplot(-1)
